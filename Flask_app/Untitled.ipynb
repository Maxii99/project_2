# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "CSV/Migration_Map_Data.csv"
migration_df = pd.read_csv(csv_file, dtype ={"Birth_Country":"str"})
migration_df.head()
# Out:
#           Birth_Country    Age_0-5 Age_6-10  Age_11-15  Age_16-20    Age_20+  \
# 0                    US        NaN      NaN        NaN        NaN        NaN
# 1                Mexico    928,523  775,875  1,485,420  2,238,925  5,753,368
# 2  EastandSoutheastAsia  1,500,243  946,080    926,337    941,610  4,334,258
# 3           CentralAsia     38,881   21,083     20,612     17,039     34,239
# 4             SouthAsia  1,148,791  589,390    446,589    470,990  1,013,222
#
#    9th_Grade  12th_Grade HS_Dropout     HS_Grad  ... Cleaning_and_maint  \
# 0  4,380,278  11,086,857    587,488  51,286,386  ...          4,183,259
# 1  3,557,555   1,818,941     26,761   2,619,905  ...            787,212
# 2    761,904     471,609      3,533   1,341,724  ...            146,691
# 3      2,938       2,164        NaN      16,565  ...              2,776
# 4    162,268     146,226      2,590     287,480  ...             27,050
#
# ...

# %%
migration_df.iloc[:,1:].astype('int32').dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3c745c2a9523> in <module>
# ----> 1 migration_df.iloc[:,1:].astype('int32').dtypes
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...
